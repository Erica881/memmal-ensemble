# %% [markdown]
# # Experiment of Hybrid Ensemble Malware Detection (GWO + PHMM + DAE + Stacked Classifier) -
# <em> Reference: https://github.com/delphi20/Malware-Detection-with-ML-DL-/blob/main </em>
#
# #####
# ### Importing the dataset

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score
from sklearn.preprocessing import StandardScaler
from mealpy import FloatVar
from mealpy.swarm_based import GWO

# ---- STEP 1: Load & prepare your dataset ----

# Load labeled malware and benign datasets
benign_df = pd.read_csv('benign_samples.csv')
malware_df = pd.read_csv('malware_samples.csv')

# Label data
benign_df['label'] = 0
malware_df['label'] = 1

# Merge and shuffle
df = pd.concat([benign_df, malware_df], axis=0).sample(frac=1).reset_index(drop=True)

# Select features and label
X = df.iloc[:, 3:-2].values  # Adjust based on real feature layout
y = df['label'].values

# Scale features
scaler = StandardScaler()
X = scaler.fit_transform(X)

n_features = X.shape[1]

# ---- STEP 2: Define your GWO-compatible objective function ----

def objective_function(solution):
    binary_mask = [1 if x > 0 else 0 for x in solution]
    
    # Avoid empty feature subset
    if sum(binary_mask) == 0:
        return 1.0

    selected_X = X[:, binary_mask]
    
    # You can switch classifiers (RandomForest, LogisticRegression, etc.)
    clf = RandomForestClassifier(random_state=42)
    
    f1 = cross_val_score(clf, selected_X, y, cv=3, scoring=make_scorer(f1_score)).mean()
    
    return 1 - f1  # because GWO minimizes the objective

# ---- STEP 3: Define the Mealpy problem ----

bounds = [FloatVar(lb=-10., ub=10., name=f"x{i}") for i in range(n_features)]

problem = {
    "bounds": bounds,
    "minmax": "min",
    "obj_func": objective_function
}

# ---- STEP 4: Run GWO ----

model = GWO.OriginalGWO(epoch=100, pop_size=30)  # You can increase epochs for better results
model.solve(problem)

# ---- STEP 5: Extract best solution ----

if model.g_best is not None and hasattr(model.g_best, "solution"):
    binary_solution = [1 if val > 0 else 0 for val in model.g_best.solution]
    selected_features = [i for i, val in enumerate(binary_solution) if val == 1]

    print("Selected feature indices:", selected_features)
    print("Fitness (1 - F1 score):", model.g_best.target)
    print("Estimated F1 score:", 1 - model.g_best.target.fitness)
else:
    print("No valid solution found.")
# Out:
# 2025/05/31 11:36:33 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: OriginalGWO(epoch=100, pop_size=30)
# 2025/05/31 11:48:20 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 1, Current best: 0.08208439471223039, Global best: 0.08208439471223039, Runtime: 368.57790 seconds
# 2025/05/31 11:53:58 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 2, Current best: 0.08208439471223039, Global best: 0.08208439471223039, Runtime: 338.40540 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 64
#      61 # ---- STEP 4: Run GWO ----
#      63 model = GWO.OriginalGWO(epoch=100, pop_size=30)  # You can increase epochs for better results
# ---> 64 model.solve(problem)
#      66 # ---- STEP 5: Extract best solution ----
#      68 if model.g_best is not None and hasattr(model.g_best, "solution"):
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\mealpy\optimizer.py:238, in Optimizer.solve(self, problem, mode, n_workers, termination, starting_solutions, seed)
#     235 time_epoch = time.perf_counter()
#     237 ## Evolve method will be called in child class
# --> 238 self.evolve(epoch)
#     240 # Update global best solution, the population is sorted or not depended on algorithm's strategy
#     241 pop_temp, self.g_best = self.update_global_best_agent(self.pop)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\mealpy\swarm_based\GWO.py:81, in OriginalGWO.evolve(self, epoch)
#      79     pop_new.append(agent)
#      80     if self.mode not in self.AVAILABLE_MODES:
# ---> 81         agent.target = self.get_target(pos_new)
#      82         self.pop[idx] = self.get_better_agent(agent, self.pop[idx], self.problem.minmax)
#      83 if self.mode in self.AVAILABLE_MODES:
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\mealpy\optimizer.py:407, in Optimizer.get_target(self, solution, counted)
#     405 if counted:
#     406     self.nfe_counter += 1
# --> 407 return self.problem.get_target(solution)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\mealpy\utils\problem.py:198, in Problem.get_target(self, solution)
#     190 def get_target(self, solution: np.ndarray) -> Target:
#     191     """
#     192     Args:
#     193         solution: The real-value solution
#    (...)    196         The target object
#     197     """
# --> 198     objs = self.obj_func(solution)
#     199     return Target(objectives=objs, weights=self.obj_weights)
#
# Cell In[44], line 47, in objective_function(solution)
#      44 # You can switch classifiers (RandomForest, LogisticRegression, etc.)
#      45 clf = RandomForestClassifier(random_state=42)
# ---> 47 f1 = cross_val_score(clf, selected_X, y, cv=3, scoring=make_scorer(f1_score)).mean()
#      49 return 1 - f1
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\model_selection\_validation.py:684, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     681 # To ensure multimetric format is not supported
#     682 scorer = check_scoring(estimator, scoring=scoring)
# --> 684 cv_results = cross_validate(
#     685     estimator=estimator,
#     686     X=X,
#     687     y=y,
#     688     groups=groups,
#     689     scoring={"score": scorer},
#     690     cv=cv,
#     691     n_jobs=n_jobs,
#     692     verbose=verbose,
#     693     params=params,
#     694     pre_dispatch=pre_dispatch,
#     695     error_score=error_score,
#     696 )
#     697 return cv_results["test_score"]
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\model_selection\_validation.py:411, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     408 # We clone the estimator to make sure that all the folds are
#     409 # independent, and that it is pickle-able.
#     410 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 411 results = parallel(
#     412     delayed(_fit_and_score)(
#     413         clone(estimator),
#     414         X,
#     415         y,
#     416         scorer=scorers,
#     417         train=train,
#     418         test=test,
#     419         verbose=verbose,
#     420         parameters=None,
#     421         fit_params=routed_params.estimator.fit,
#     422         score_params=routed_params.scorer.score,
#     423         return_train_score=return_train_score,
#     424         return_times=True,
#     425         return_estimator=return_estimator,
#     426         error_score=error_score,
#     427     )
#     428     for train, test in indices
#     429 )
#     431 _warn_or_raise_about_fit_failures(results, error_score)
#     433 # For callable scoring, the return type is only know after calling. If the
#     434 # return type is a dictionary, the error scores can now be inserted with
#     435 # the correct key.
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\model_selection\_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\ensemble\_forest.py:487, in BaseForest.fit(self, X, y, sample_weight)
#     476 trees = [
#     477     self._make_estimator(append=False, random_state=random_state)
#     478     for i in range(n_more_estimators)
#     479 ]
#     481 # Parallel loop: we prefer the threading backend as the Cython code
#     482 # for fitting the trees is internally releasing the Python GIL
#     483 # making threading more efficient than multiprocessing in
#     484 # that case. However, for joblib 0.12+ we respect any
#     485 # parallel_backend contexts set at a higher level,
#     486 # since correctness does not rely on using threads.
# --> 487 trees = Parallel(
#     488     n_jobs=self.n_jobs,
#     489     verbose=self.verbose,
#     490     prefer="threads",
#     491 )(
#     492     delayed(_parallel_build_trees)(
#     493         t,
#     494         self.bootstrap,
#     495         X,
#     496         y,
#     497         sample_weight,
#     498         i,
#     499         len(trees),
#     500         verbose=self.verbose,
#     501         class_weight=self.class_weight,
#     502         n_samples_bootstrap=n_samples_bootstrap,
#     503         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     504     )
#     505     for i, t in enumerate(trees)
#     506 )
#     508 # Collect newly grown trees
#     509 self.estimators_.extend(trees)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree._fit(
#     190         X,
#     191         y,
#     192         sample_weight=curr_sample_weight,
#     193         check_input=False,
#     194         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     195     )
#     196 else:
#     197     tree._fit(
#     198         X,
#     199         y,
#    (...)    202         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     203     )
#
# File c:\Users\Kah Wei\Desktop\temp_FYP\.env\Lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)    469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
import pandas as pd
import torch


# Step 1: Load the data
benign_df = pd.read_csv('benign_samples.csv')   # CSV with benign samples
malware_df = pd.read_csv('malware_samples.csv') # CSV with malware samples

# Step 2: Label the data
benign_df['label'] = 0  # Label all benign samples as 0
malware_df['label'] = 1  # Label all malware samples as 1

# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler

# Merge and suffle the data
df = pd.concat([malware_df, benign_df], axis=0).reset_index(drop=True)
df = df.sample(frac=1).reset_index(drop=True)

# Split features and target
X = df.iloc[:, 3:-2].values  # adjust based on your actual feature columns
y = df['label'].values

# Scale features
scaler = StandardScaler()
X = scaler.fit_transform(X)

n_features = X.shape[1]

# %% [markdown]
# ### Add Feature Selection - GWO for optimizing weights before discretization

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import cross_val_score
# def fitness(solution):
#     binary_solution = [1 if val > 0 else 0 for val in solution]
#     selected_idx = [i for i, bit in enumerate(binary_solution) if bit == 1]

#     if not selected_idx:  # avoid empty feature set
#         return 1.0

#     X_selected = X[:, selected_idx]
#     clf = RandomForestClassifier(n_estimators=50, random_state=42)
#     score = cross_val_score(clf, X_selected, y, cv=3, scoring='f1', n_jobs=-1).mean()

#     return 1 - score  # because GWO minimizes

# %% [markdown]
# ### Add Feature Selection - GWO for optimizing weights before discretization

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score

def objective_function(solution):
    binary_mask = [1 if x > 0 else 0 for x in solution]
    
    # Avoid empty feature subset
    if sum(binary_mask) == 0:
        return 1.0

    selected_X = X[:, binary_mask]
    
    # You can switch classifiers (RandomForest, LogisticRegression, etc.)
    clf = RandomForestClassifier(random_state=42)
    
    f1 = cross_val_score(clf, selected_X, y, cv=3, scoring=make_scorer(f1_score)).mean()
    
    return 1 - f1  # because GWO minimizes the objective

# %%
import numpy as np
from mealpy import FloatVar
from mealpy.swarm_based import GWO
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# def objective_function(solution):
#     return np.sum(solution**2)

# X, y = load_breast_cancer(return_X_y=True)  # Replace with your dataset

def objective_function(solution):
    # Convert float solution to binary mask
    mask = [1 if x > 0 else 0 for x in solution]
    if sum(mask) == 0:  # Avoid empty feature set
        return 1.0
    X_selected = X[:, mask]
    clf = RandomForestClassifier()
    f1 = cross_val_score(clf, X_selected, y, scoring='f1', cv=3).mean()
    return 1 - f1


bounds = [FloatVar(lb=-10., ub=10., name=f"x{i}") for i in range(30)] 

problem_dict = {
    "bounds": bounds,
    "minmax": "min",
    "obj_func": objective_function
}

model = GWO.OriginalGWO(epoch=1000, pop_size=50)
result = model.solve(problem_dict)
if model.g_best is not None:
    if hasattr(model.g_best, "solution") and hasattr(model.g_best, "target"):
        print(f"Solution: {model.g_best.solution}, Fitness: {model.g_best.target}")
        # Get binary solution
        binary_solution = [1 if val > 0 else 0 for val in model.g_best.solution]
        selected_features = [i for i, val in enumerate(binary_solution) if val == 1]

        print("Selected feature indices:", selected_features)
        print("Fitness (1 - F1 score):", model.g_best.target)
        print("Estimated F1 score:", model.g_best.target.fitness)
    else:
        print("Best agent attributes:", dir(model.g_best))
        print("Best agent object:", model.g_best)
else:
    print("No best solution found. model.g_best is None.")
# Out:
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: OriginalGWO(epoch=1000, pop_size=50)
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 1, Current best: 499.2756586709646, Global best: 499.2756586709646, Runtime: 0.02000 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 2, Current best: 357.8251815085439, Global best: 357.8251815085439, Runtime: 0.01751 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 3, Current best: 295.3785289691553, Global best: 295.3785289691553, Runtime: 0.01806 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 4, Current best: 200.01863026453, Global best: 200.01863026453, Runtime: 0.01842 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 5, Current best: 172.57887533305563, Global best: 172.57887533305563, Runtime: 0.01657 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 6, Current best: 101.0742937705907, Global best: 101.0742937705907, Runtime: 0.01714 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 7, Current best: 100.80568062869628, Global best: 100.80568062869628, Runtime: 0.01538 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 8, Current best: 72.47519869402174, Global best: 72.47519869402174, Runtime: 0.01788 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 9, Current best: 55.04947720564658, Global best: 55.04947720564658, Runtime: 0.01647 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 10, Current best: 42.47889923368117, Global best: 42.47889923368117, Runtime: 0.01505 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 11, Current best: 26.2648156779817, Global best: 26.2648156779817, Runtime: 0.01515 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 12, Current best: 23.503988078715132, Global best: 23.503988078715132, Runtime: 0.01607 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 13, Current best: 17.173135677458788, Global best: 17.173135677458788, Runtime: 0.01597 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 14, Current best: 14.13648390614347, Global best: 14.13648390614347, Runtime: 0.01507 seconds
# 2025/05/31 11:28:36 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 15, Current best: 8.339866741162256, Global best: 8.339866741162256, Runtime: 0.01747 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 16, Current best: 7.8899135632723665, Global best: 7.8899135632723665, Runtime: 0.01851 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 17, Current best: 6.037857559556143, Global best: 6.037857559556143, Runtime: 0.01845 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 18, Current best: 5.677479091826879, Global best: 5.677479091826879, Runtime: 0.01503 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 19, Current best: 4.792692832089269, Global best: 4.792692832089269, Runtime: 0.01521 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 20, Current best: 3.1578264106507006, Global best: 3.1578264106507006, Runtime: 0.01656 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 21, Current best: 2.5144714075659538, Global best: 2.5144714075659538, Runtime: 0.01833 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 22, Current best: 1.5474466865335716, Global best: 1.5474466865335716, Runtime: 0.01698 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 23, Current best: 0.8410348601580354, Global best: 0.8410348601580354, Runtime: 0.01596 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 24, Current best: 0.7583239949339496, Global best: 0.7583239949339496, Runtime: 0.01508 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 25, Current best: 0.725987900923527, Global best: 0.725987900923527, Runtime: 0.01544 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 26, Current best: 0.40146046550165093, Global best: 0.40146046550165093, Runtime: 0.01595 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 27, Current best: 0.40146046550165093, Global best: 0.40146046550165093, Runtime: 0.01526 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 28, Current best: 0.2631503021461036, Global best: 0.2631503021461036, Runtime: 0.01554 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 29, Current best: 0.1537407150481265, Global best: 0.1537407150481265, Runtime: 0.01662 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 30, Current best: 0.13548630768159095, Global best: 0.13548630768159095, Runtime: 0.01632 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 31, Current best: 0.08620247388202686, Global best: 0.08620247388202686, Runtime: 0.01781 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 32, Current best: 0.08620247388202686, Global best: 0.08620247388202686, Runtime: 0.01561 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 33, Current best: 0.0624386632896459, Global best: 0.0624386632896459, Runtime: 0.01573 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 34, Current best: 0.042888678418645194, Global best: 0.042888678418645194, Runtime: 0.01501 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 35, Current best: 0.03185102712940165, Global best: 0.03185102712940165, Runtime: 0.01578 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 36, Current best: 0.020352944344335034, Global best: 0.020352944344335034, Runtime: 0.01619 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 37, Current best: 0.01620139115562264, Global best: 0.01620139115562264, Runtime: 0.01551 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 38, Current best: 0.011431608605522461, Global best: 0.011431608605522461, Runtime: 0.01683 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 39, Current best: 0.010923376280045265, Global best: 0.010923376280045265, Runtime: 0.01756 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 40, Current best: 0.00783857292830654, Global best: 0.00783857292830654, Runtime: 0.01650 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 41, Current best: 0.005824721110025853, Global best: 0.005824721110025853, Runtime: 0.01561 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 42, Current best: 0.00469387263957639, Global best: 0.00469387263957639, Runtime: 0.01661 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 43, Current best: 0.003421319180927469, Global best: 0.003421319180927469, Runtime: 0.01777 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 44, Current best: 0.0030330987542792447, Global best: 0.0030330987542792447, Runtime: 0.01553 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 45, Current best: 0.0018364407233565218, Global best: 0.0018364407233565218, Runtime: 0.01873 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 46, Current best: 0.0011566945704539883, Global best: 0.0011566945704539883, Runtime: 0.01689 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 47, Current best: 0.0009054492085251144, Global best: 0.0009054492085251144, Runtime: 0.01597 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 48, Current best: 0.0006269708672823091, Global best: 0.0006269708672823091, Runtime: 0.01688 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 49, Current best: 0.00046130172421228954, Global best: 0.00046130172421228954, Runtime: 0.01594 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 50, Current best: 0.00040872106169343564, Global best: 0.00040872106169343564, Runtime: 0.01524 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 51, Current best: 0.00025966908454521867, Global best: 0.00025966908454521867, Runtime: 0.01497 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 52, Current best: 0.0001912855347959106, Global best: 0.0001912855347959106, Runtime: 0.01559 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 53, Current best: 0.0001912855347959106, Global best: 0.0001912855347959106, Runtime: 0.01520 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 54, Current best: 0.0001481269892569984, Global best: 0.0001481269892569984, Runtime: 0.01660 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 55, Current best: 9.564398533832252e-05, Global best: 9.564398533832252e-05, Runtime: 0.01539 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 56, Current best: 7.634613585654274e-05, Global best: 7.634613585654274e-05, Runtime: 0.01726 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 57, Current best: 5.787050981879119e-05, Global best: 5.787050981879119e-05, Runtime: 0.01810 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 58, Current best: 4.3133862359317e-05, Global best: 4.3133862359317e-05, Runtime: 0.01624 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 59, Current best: 2.7177375813976436e-05, Global best: 2.7177375813976436e-05, Runtime: 0.01582 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 60, Current best: 2.3243716885679757e-05, Global best: 2.3243716885679757e-05, Runtime: 0.01571 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 61, Current best: 2.0530990866468687e-05, Global best: 2.0530990866468687e-05, Runtime: 0.01591 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 62, Current best: 1.5771562656510127e-05, Global best: 1.5771562656510127e-05, Runtime: 0.01689 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 63, Current best: 9.524972632018997e-06, Global best: 9.524972632018997e-06, Runtime: 0.01611 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 64, Current best: 6.596370562055737e-06, Global best: 6.596370562055737e-06, Runtime: 0.01533 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 65, Current best: 5.450353577188645e-06, Global best: 5.450353577188645e-06, Runtime: 0.01585 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 66, Current best: 3.818323444402328e-06, Global best: 3.818323444402328e-06, Runtime: 0.01660 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 67, Current best: 3.0914646276989636e-06, Global best: 3.0914646276989636e-06, Runtime: 0.01698 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 68, Current best: 2.118301319221107e-06, Global best: 2.118301319221107e-06, Runtime: 0.01605 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 69, Current best: 1.6939248954580464e-06, Global best: 1.6939248954580464e-06, Runtime: 0.01559 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 70, Current best: 1.2943212859742735e-06, Global best: 1.2943212859742735e-06, Runtime: 0.01609 seconds
# 2025/05/31 11:28:37 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 71, Current best: 7.998593506768039e-07, Global best: 7.998593506768039e-07, Runtime: 0.01744 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 72, Current best: 5.642923522718606e-07, Global best: 5.642923522718606e-07, Runtime: 0.01729 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 73, Current best: 3.156890650278842e-07, Global best: 3.156890650278842e-07, Runtime: 0.01599 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 74, Current best: 2.692162670170978e-07, Global best: 2.692162670170978e-07, Runtime: 0.01551 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 75, Current best: 1.920660258754158e-07, Global best: 1.920660258754158e-07, Runtime: 0.01568 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 76, Current best: 1.511744222425239e-07, Global best: 1.511744222425239e-07, Runtime: 0.01558 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 77, Current best: 1.1326758374844483e-07, Global best: 1.1326758374844483e-07, Runtime: 0.01556 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 78, Current best: 8.610400090895576e-08, Global best: 8.610400090895576e-08, Runtime: 0.01745 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 79, Current best: 4.997447495502017e-08, Global best: 4.997447495502017e-08, Runtime: 0.01780 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 80, Current best: 1.9726341641586942e-08, Global best: 1.9726341641586942e-08, Runtime: 0.01663 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 81, Current best: 1.9726341641586942e-08, Global best: 1.9726341641586942e-08, Runtime: 0.01524 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 82, Current best: 1.1397729521346997e-08, Global best: 1.1397729521346997e-08, Runtime: 0.01555 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 83, Current best: 1.0486312984501894e-08, Global best: 1.0486312984501894e-08, Runtime: 0.01594 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 84, Current best: 6.398387860944835e-09, Global best: 6.398387860944835e-09, Runtime: 0.01539 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 85, Current best: 3.7359981845382934e-09, Global best: 3.7359981845382934e-09, Runtime: 0.01558 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 86, Current best: 3.2490789226138517e-09, Global best: 3.2490789226138517e-09, Runtime: 0.01587 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 87, Current best: 2.060275677497911e-09, Global best: 2.060275677497911e-09, Runtime: 0.01710 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 88, Current best: 1.4322995531939823e-09, Global best: 1.4322995531939823e-09, Runtime: 0.01533 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 89, Current best: 1.0531050806861191e-09, Global best: 1.0531050806861191e-09, Runtime: 0.01554 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 90, Current best: 7.553115094593972e-10, Global best: 7.553115094593972e-10, Runtime: 0.01701 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 91, Current best: 5.984135841549955e-10, Global best: 5.984135841549955e-10, Runtime: 0.01508 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 92, Current best: 4.633928231908553e-10, Global best: 4.633928231908553e-10, Runtime: 0.01488 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 93, Current best: 3.830678547229329e-10, Global best: 3.830678547229329e-10, Runtime: 0.01500 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 94, Current best: 2.8602200028937004e-10, Global best: 2.8602200028937004e-10, Runtime: 0.01535 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 95, Current best: 1.9684939901053507e-10, Global best: 1.9684939901053507e-10, Runtime: 0.01673 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 96, Current best: 1.4960825451332247e-10, Global best: 1.4960825451332247e-10, Runtime: 0.01682 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 97, Current best: 1.0905453536286052e-10, Global best: 1.0905453536286052e-10, Runtime: 0.01544 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 98, Current best: 7.959171361437679e-11, Global best: 7.959171361437679e-11, Runtime: 0.02098 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 99, Current best: 6.592175024857531e-11, Global best: 6.592175024857531e-11, Runtime: 0.01621 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 100, Current best: 4.2948863796920304e-11, Global best: 4.2948863796920304e-11, Runtime: 0.01555 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 101, Current best: 3.156146318205898e-11, Global best: 3.156146318205898e-11, Runtime: 0.01544 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 102, Current best: 2.2260960809874903e-11, Global best: 2.2260960809874903e-11, Runtime: 0.01665 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 103, Current best: 1.8184284938355668e-11, Global best: 1.8184284938355668e-11, Runtime: 0.01580 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 104, Current best: 9.565102380872756e-12, Global best: 9.565102380872756e-12, Runtime: 0.01545 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 105, Current best: 8.224037408803794e-12, Global best: 8.224037408803794e-12, Runtime: 0.01493 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 106, Current best: 6.4456302066949135e-12, Global best: 6.4456302066949135e-12, Runtime: 0.01590 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 107, Current best: 5.103234690265793e-12, Global best: 5.103234690265793e-12, Runtime: 0.01595 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 108, Current best: 3.465760473755761e-12, Global best: 3.465760473755761e-12, Runtime: 0.01595 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 109, Current best: 2.202801421584999e-12, Global best: 2.202801421584999e-12, Runtime: 0.01756 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 110, Current best: 1.5817916204814352e-12, Global best: 1.5817916204814352e-12, Runtime: 0.01585 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 111, Current best: 1.3133303542617836e-12, Global best: 1.3133303542617836e-12, Runtime: 0.01637 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 112, Current best: 8.766108283383369e-13, Global best: 8.766108283383369e-13, Runtime: 0.01544 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 113, Current best: 4.887148603687015e-13, Global best: 4.887148603687015e-13, Runtime: 0.01580 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 114, Current best: 3.9531385967107115e-13, Global best: 3.9531385967107115e-13, Runtime: 0.01647 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 115, Current best: 2.7483936417220413e-13, Global best: 2.7483936417220413e-13, Runtime: 0.01698 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 116, Current best: 2.3182223071215013e-13, Global best: 2.3182223071215013e-13, Runtime: 0.01676 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 117, Current best: 1.4121842646380164e-13, Global best: 1.4121842646380164e-13, Runtime: 0.01683 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 118, Current best: 9.898530016665584e-14, Global best: 9.898530016665584e-14, Runtime: 0.01581 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 119, Current best: 7.41432087045926e-14, Global best: 7.41432087045926e-14, Runtime: 0.01616 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 120, Current best: 5.5175837677138514e-14, Global best: 5.5175837677138514e-14, Runtime: 0.01571 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 121, Current best: 3.671856922877666e-14, Global best: 3.671856922877666e-14, Runtime: 0.01531 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 122, Current best: 2.6136466045611434e-14, Global best: 2.6136466045611434e-14, Runtime: 0.01546 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 123, Current best: 1.564742802883486e-14, Global best: 1.564742802883486e-14, Runtime: 0.01583 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 124, Current best: 1.5504312051648977e-14, Global best: 1.5504312051648977e-14, Runtime: 0.01664 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 125, Current best: 9.204921392234024e-15, Global best: 9.204921392234024e-15, Runtime: 0.01596 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 126, Current best: 7.418983844682462e-15, Global best: 7.418983844682462e-15, Runtime: 0.01589 seconds
# 2025/05/31 11:28:38 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 127, Current best: 5.09357757667532e-15, Global best: 5.09357757667532e-15, Runtime: 0.01657 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 128, Current best: 2.7245144133873602e-15, Global best: 2.7245144133873602e-15, Runtime: 0.01672 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 129, Current best: 2.317700258884171e-15, Global best: 2.317700258884171e-15, Runtime: 0.01712 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 130, Current best: 1.6602243898524146e-15, Global best: 1.6602243898524146e-15, Runtime: 0.01525 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 131, Current best: 8.868958139612532e-16, Global best: 8.868958139612532e-16, Runtime: 0.01611 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 132, Current best: 7.478965626256677e-16, Global best: 7.478965626256677e-16, Runtime: 0.01640 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 133, Current best: 4.4276488639782876e-16, Global best: 4.4276488639782876e-16, Runtime: 0.01540 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 134, Current best: 3.5476018957765066e-16, Global best: 3.5476018957765066e-16, Runtime: 0.01597 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 135, Current best: 3.17616899812022e-16, Global best: 3.17616899812022e-16, Runtime: 0.01649 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 136, Current best: 2.531781073636883e-16, Global best: 2.531781073636883e-16, Runtime: 0.01630 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 137, Current best: 1.2258698438676494e-16, Global best: 1.2258698438676494e-16, Runtime: 0.01618 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 138, Current best: 1.0365562768282663e-16, Global best: 1.0365562768282663e-16, Runtime: 0.01708 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 139, Current best: 8.007665472339584e-17, Global best: 8.007665472339584e-17, Runtime: 0.01568 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 140, Current best: 6.429966625409521e-17, Global best: 6.429966625409521e-17, Runtime: 0.01516 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 141, Current best: 3.6381572848656484e-17, Global best: 3.6381572848656484e-17, Runtime: 0.01555 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 142, Current best: 2.8844765017376094e-17, Global best: 2.8844765017376094e-17, Runtime: 0.02104 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 143, Current best: 2.0916431309499092e-17, Global best: 2.0916431309499092e-17, Runtime: 0.02706 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 144, Current best: 1.3780256354443974e-17, Global best: 1.3780256354443974e-17, Runtime: 0.02180 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 145, Current best: 9.26869211412662e-18, Global best: 9.26869211412662e-18, Runtime: 0.02080 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 146, Current best: 5.738068838369558e-18, Global best: 5.738068838369558e-18, Runtime: 0.01677 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 147, Current best: 4.225013243614724e-18, Global best: 4.225013243614724e-18, Runtime: 0.01577 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 148, Current best: 2.523563951520723e-18, Global best: 2.523563951520723e-18, Runtime: 0.01716 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 149, Current best: 1.3867033172861824e-18, Global best: 1.3867033172861824e-18, Runtime: 0.01885 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 150, Current best: 1.171505266849466e-18, Global best: 1.171505266849466e-18, Runtime: 0.01542 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 151, Current best: 8.615976821640694e-19, Global best: 8.615976821640694e-19, Runtime: 0.01613 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 152, Current best: 4.837308438857708e-19, Global best: 4.837308438857708e-19, Runtime: 0.01579 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 153, Current best: 3.326402958232212e-19, Global best: 3.326402958232212e-19, Runtime: 0.01680 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 154, Current best: 2.599448575745672e-19, Global best: 2.599448575745672e-19, Runtime: 0.01967 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 155, Current best: 1.9265258290829198e-19, Global best: 1.9265258290829198e-19, Runtime: 0.01504 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 156, Current best: 1.2014555729802262e-19, Global best: 1.2014555729802262e-19, Runtime: 0.01562 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 157, Current best: 1.0774289394054686e-19, Global best: 1.0774289394054686e-19, Runtime: 0.01483 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 158, Current best: 7.038242602806021e-20, Global best: 7.038242602806021e-20, Runtime: 0.01635 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 159, Current best: 6.045398192431388e-20, Global best: 6.045398192431388e-20, Runtime: 0.01651 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 160, Current best: 4.5210710559437204e-20, Global best: 4.5210710559437204e-20, Runtime: 0.01711 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 161, Current best: 2.943879760407937e-20, Global best: 2.943879760407937e-20, Runtime: 0.01607 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 162, Current best: 2.0040250006708372e-20, Global best: 2.0040250006708372e-20, Runtime: 0.01554 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 163, Current best: 1.1448229690102314e-20, Global best: 1.1448229690102314e-20, Runtime: 0.01576 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 164, Current best: 6.0551775230589866e-21, Global best: 6.0551775230589866e-21, Runtime: 0.01719 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 165, Current best: 5.639729173940233e-21, Global best: 5.639729173940233e-21, Runtime: 0.01595 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 166, Current best: 3.4782701792573745e-21, Global best: 3.4782701792573745e-21, Runtime: 0.01669 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 167, Current best: 2.764956832917973e-21, Global best: 2.764956832917973e-21, Runtime: 0.01505 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 168, Current best: 1.4710937548501306e-21, Global best: 1.4710937548501306e-21, Runtime: 0.01597 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 169, Current best: 1.0524543350458834e-21, Global best: 1.0524543350458834e-21, Runtime: 0.01647 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 170, Current best: 5.946535983257046e-22, Global best: 5.946535983257046e-22, Runtime: 0.01644 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 171, Current best: 5.279949474722452e-22, Global best: 5.279949474722452e-22, Runtime: 0.01573 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 172, Current best: 3.854233630723223e-22, Global best: 3.854233630723223e-22, Runtime: 0.01695 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 173, Current best: 2.516697689766802e-22, Global best: 2.516697689766802e-22, Runtime: 0.01703 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 174, Current best: 1.7906540031415684e-22, Global best: 1.7906540031415684e-22, Runtime: 0.01914 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 175, Current best: 1.160638183902613e-22, Global best: 1.160638183902613e-22, Runtime: 0.01705 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 176, Current best: 8.156734372631703e-23, Global best: 8.156734372631703e-23, Runtime: 0.01594 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 177, Current best: 6.949053618792813e-23, Global best: 6.949053618792813e-23, Runtime: 0.01707 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 178, Current best: 3.2387843825789077e-23, Global best: 3.2387843825789077e-23, Runtime: 0.01513 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 179, Current best: 2.315444782264038e-23, Global best: 2.315444782264038e-23, Runtime: 0.01678 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 180, Current best: 1.7702489340968035e-23, Global best: 1.7702489340968035e-23, Runtime: 0.01665 seconds
# 2025/05/31 11:28:39 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 181, Current best: 1.3886841364830044e-23, Global best: 1.3886841364830044e-23, Runtime: 0.01804 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 182, Current best: 9.980284213767038e-24, Global best: 9.980284213767038e-24, Runtime: 0.01862 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 183, Current best: 8.784495286270536e-24, Global best: 8.784495286270536e-24, Runtime: 0.01521 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 184, Current best: 6.375334588553456e-24, Global best: 6.375334588553456e-24, Runtime: 0.01517 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 185, Current best: 4.4499162367166404e-24, Global best: 4.4499162367166404e-24, Runtime: 0.01828 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 186, Current best: 3.135369831965918e-24, Global best: 3.135369831965918e-24, Runtime: 0.01550 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 187, Current best: 1.748261682784967e-24, Global best: 1.748261682784967e-24, Runtime: 0.02046 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 188, Current best: 1.1035701335968301e-24, Global best: 1.1035701335968301e-24, Runtime: 0.01593 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 189, Current best: 8.028452995272241e-25, Global best: 8.028452995272241e-25, Runtime: 0.01664 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 190, Current best: 4.873035446313779e-25, Global best: 4.873035446313779e-25, Runtime: 0.01690 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 191, Current best: 3.3155829430313235e-25, Global best: 3.3155829430313235e-25, Runtime: 0.01569 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 192, Current best: 2.4787926301947736e-25, Global best: 2.4787926301947736e-25, Runtime: 0.01706 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 193, Current best: 1.7078750471043939e-25, Global best: 1.7078750471043939e-25, Runtime: 0.01659 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 194, Current best: 1.3487890680993128e-25, Global best: 1.3487890680993128e-25, Runtime: 0.01516 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 195, Current best: 1.1059460300346415e-25, Global best: 1.1059460300346415e-25, Runtime: 0.01562 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 196, Current best: 7.133761090409078e-26, Global best: 7.133761090409078e-26, Runtime: 0.01682 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 197, Current best: 5.286401201782386e-26, Global best: 5.286401201782386e-26, Runtime: 0.01722 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 198, Current best: 3.865934615807668e-26, Global best: 3.865934615807668e-26, Runtime: 0.01517 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 199, Current best: 2.9255789543404163e-26, Global best: 2.9255789543404163e-26, Runtime: 0.01678 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 200, Current best: 1.6535000266769174e-26, Global best: 1.6535000266769174e-26, Runtime: 0.01559 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 201, Current best: 9.805703444299318e-27, Global best: 9.805703444299318e-27, Runtime: 0.01890 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 202, Current best: 8.227316840430392e-27, Global best: 8.227316840430392e-27, Runtime: 0.01476 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 203, Current best: 6.071626807448957e-27, Global best: 6.071626807448957e-27, Runtime: 0.01549 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 204, Current best: 4.304428212251523e-27, Global best: 4.304428212251523e-27, Runtime: 0.01620 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 205, Current best: 2.7427083983355968e-27, Global best: 2.7427083983355968e-27, Runtime: 0.01862 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 206, Current best: 1.843977113764288e-27, Global best: 1.843977113764288e-27, Runtime: 0.01514 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 207, Current best: 1.0995420516684785e-27, Global best: 1.0995420516684785e-27, Runtime: 0.01510 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 208, Current best: 8.068575048172915e-28, Global best: 8.068575048172915e-28, Runtime: 0.01676 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 209, Current best: 4.910089718269507e-28, Global best: 4.910089718269507e-28, Runtime: 0.01616 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 210, Current best: 4.0334256986555253e-28, Global best: 4.0334256986555253e-28, Runtime: 0.01699 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 211, Current best: 3.0004190268676787e-28, Global best: 3.0004190268676787e-28, Runtime: 0.01621 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 212, Current best: 2.0717913060383207e-28, Global best: 2.0717913060383207e-28, Runtime: 0.01531 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 213, Current best: 1.4266227900949134e-28, Global best: 1.4266227900949134e-28, Runtime: 0.02133 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 214, Current best: 1.1383400561396996e-28, Global best: 1.1383400561396996e-28, Runtime: 0.01551 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 215, Current best: 8.712509521118539e-29, Global best: 8.712509521118539e-29, Runtime: 0.01492 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 216, Current best: 6.616994308841372e-29, Global best: 6.616994308841372e-29, Runtime: 0.01517 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 217, Current best: 4.5086403947949973e-29, Global best: 4.5086403947949973e-29, Runtime: 0.01613 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 218, Current best: 3.1916127014533457e-29, Global best: 3.1916127014533457e-29, Runtime: 0.01725 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 219, Current best: 2.0164815680493732e-29, Global best: 2.0164815680493732e-29, Runtime: 0.01634 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 220, Current best: 1.65501715674207e-29, Global best: 1.65501715674207e-29, Runtime: 0.01611 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 221, Current best: 1.2523887552119483e-29, Global best: 1.2523887552119483e-29, Runtime: 0.01489 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 222, Current best: 8.889449560636118e-30, Global best: 8.889449560636118e-30, Runtime: 0.01630 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 223, Current best: 6.592582010992235e-30, Global best: 6.592582010992235e-30, Runtime: 0.01532 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 224, Current best: 3.525896146935506e-30, Global best: 3.525896146935506e-30, Runtime: 0.01692 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 225, Current best: 2.551935794629956e-30, Global best: 2.551935794629956e-30, Runtime: 0.01726 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 226, Current best: 1.3920710582565385e-30, Global best: 1.3920710582565385e-30, Runtime: 0.01619 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 227, Current best: 1.0246149932792748e-30, Global best: 1.0246149932792748e-30, Runtime: 0.01526 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 228, Current best: 6.482870661869939e-31, Global best: 6.482870661869939e-31, Runtime: 0.02209 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 229, Current best: 5.043613835719788e-31, Global best: 5.043613835719788e-31, Runtime: 0.01587 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 230, Current best: 3.6927170306832404e-31, Global best: 3.6927170306832404e-31, Runtime: 0.01509 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 231, Current best: 2.3159132584219635e-31, Global best: 2.3159132584219635e-31, Runtime: 0.01536 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 232, Current best: 1.6761841149589695e-31, Global best: 1.6761841149589695e-31, Runtime: 0.01594 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 233, Current best: 8.976396054532539e-32, Global best: 8.976396054532539e-32, Runtime: 0.02049 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 234, Current best: 6.941639963651431e-32, Global best: 6.941639963651431e-32, Runtime: 0.01908 seconds
# 2025/05/31 11:28:40 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 235, Current best: 5.196717036336095e-32, Global best: 5.196717036336095e-32, Runtime: 0.01738 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 236, Current best: 2.583898370704592e-32, Global best: 2.583898370704592e-32, Runtime: 0.01948 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 237, Current best: 2.0154857829619615e-32, Global best: 2.0154857829619615e-32, Runtime: 0.01577 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 238, Current best: 1.431135354502739e-32, Global best: 1.431135354502739e-32, Runtime: 0.01552 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 239, Current best: 8.826276709447145e-33, Global best: 8.826276709447145e-33, Runtime: 0.01624 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 240, Current best: 6.441503660994646e-33, Global best: 6.441503660994646e-33, Runtime: 0.01511 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 241, Current best: 5.559029869264411e-33, Global best: 5.559029869264411e-33, Runtime: 0.01503 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 242, Current best: 3.800708039624423e-33, Global best: 3.800708039624423e-33, Runtime: 0.01759 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 243, Current best: 2.283315321939389e-33, Global best: 2.283315321939389e-33, Runtime: 0.01675 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 244, Current best: 1.6844888287201407e-33, Global best: 1.6844888287201407e-33, Runtime: 0.01471 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 245, Current best: 1.0725959141958923e-33, Global best: 1.0725959141958923e-33, Runtime: 0.01633 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 246, Current best: 6.4398353696964186e-34, Global best: 6.4398353696964186e-34, Runtime: 0.01606 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 247, Current best: 5.053759928006803e-34, Global best: 5.053759928006803e-34, Runtime: 0.01767 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 248, Current best: 3.2805312244150134e-34, Global best: 3.2805312244150134e-34, Runtime: 0.01620 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 249, Current best: 2.4378939121854376e-34, Global best: 2.4378939121854376e-34, Runtime: 0.01969 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 250, Current best: 1.3023117681572367e-34, Global best: 1.3023117681572367e-34, Runtime: 0.02158 seconds
# 2025/05/31 11:28:41 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 251, Current best: 1.0695264994722924e-34, Global best: 1.0695264994722924e-34, Runtime: 0.01696 seconds
# ...
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 922, Current best: 1.5622294483742564e-79, Global best: 1.5622294483742564e-79, Runtime: 0.01724 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 923, Current best: 1.531776142989555e-79, Global best: 1.531776142989555e-79, Runtime: 0.01617 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 924, Current best: 1.50245703807016e-79, Global best: 1.50245703807016e-79, Runtime: 0.01731 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 925, Current best: 1.4762409286873095e-79, Global best: 1.4762409286873095e-79, Runtime: 0.01671 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 926, Current best: 1.4368299115696847e-79, Global best: 1.4368299115696847e-79, Runtime: 0.01563 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 927, Current best: 1.3976585208942498e-79, Global best: 1.3976585208942498e-79, Runtime: 0.01551 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 928, Current best: 1.3762523371858522e-79, Global best: 1.3762523371858522e-79, Runtime: 0.01613 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 929, Current best: 1.3323901873563713e-79, Global best: 1.3323901873563713e-79, Runtime: 0.02212 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 930, Current best: 1.2993683225425925e-79, Global best: 1.2993683225425925e-79, Runtime: 0.01785 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 931, Current best: 1.2779021044214238e-79, Global best: 1.2779021044214238e-79, Runtime: 0.01582 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 932, Current best: 1.256911438904996e-79, Global best: 1.256911438904996e-79, Runtime: 0.01758 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 933, Current best: 1.2281314706717309e-79, Global best: 1.2281314706717309e-79, Runtime: 0.01681 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 934, Current best: 1.1829839742488389e-79, Global best: 1.1829839742488389e-79, Runtime: 0.02131 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 935, Current best: 1.1754400020472649e-79, Global best: 1.1754400020472649e-79, Runtime: 0.01810 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 936, Current best: 1.1604091749476021e-79, Global best: 1.1604091749476021e-79, Runtime: 0.01576 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 937, Current best: 1.145249203030528e-79, Global best: 1.145249203030528e-79, Runtime: 0.01617 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 938, Current best: 1.1266473766100512e-79, Global best: 1.1266473766100512e-79, Runtime: 0.01663 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 939, Current best: 1.1164453561995236e-79, Global best: 1.1164453561995236e-79, Runtime: 0.01583 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 940, Current best: 1.0897434993599915e-79, Global best: 1.0897434993599915e-79, Runtime: 0.01604 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 941, Current best: 1.0840126157484972e-79, Global best: 1.0840126157484972e-79, Runtime: 0.02719 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 942, Current best: 1.0678455886730236e-79, Global best: 1.0678455886730236e-79, Runtime: 0.02149 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 943, Current best: 1.0521687444204955e-79, Global best: 1.0521687444204955e-79, Runtime: 0.02268 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 944, Current best: 1.0322003282052013e-79, Global best: 1.0322003282052013e-79, Runtime: 0.02747 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 945, Current best: 1.0190794433453435e-79, Global best: 1.0190794433453435e-79, Runtime: 0.01905 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 946, Current best: 1.0025932226785973e-79, Global best: 1.0025932226785973e-79, Runtime: 0.01587 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 947, Current best: 9.874193907792143e-80, Global best: 9.874193907792143e-80, Runtime: 0.01482 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 948, Current best: 9.677503554770438e-80, Global best: 9.677503554770438e-80, Runtime: 0.01812 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 949, Current best: 9.61609762191157e-80, Global best: 9.61609762191157e-80, Runtime: 0.01696 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 950, Current best: 9.448187160474554e-80, Global best: 9.448187160474554e-80, Runtime: 0.01592 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 951, Current best: 9.42610189461111e-80, Global best: 9.42610189461111e-80, Runtime: 0.01685 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 952, Current best: 9.305234040706963e-80, Global best: 9.305234040706963e-80, Runtime: 0.01566 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 953, Current best: 9.188216293756535e-80, Global best: 9.188216293756535e-80, Runtime: 0.01639 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 954, Current best: 9.07691271785558e-80, Global best: 9.07691271785558e-80, Runtime: 0.01621 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 955, Current best: 8.945075694322632e-80, Global best: 8.945075694322632e-80, Runtime: 0.01621 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 956, Current best: 8.822778422291499e-80, Global best: 8.822778422291499e-80, Runtime: 0.02177 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 957, Current best: 8.701038323578158e-80, Global best: 8.701038323578158e-80, Runtime: 0.01840 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 958, Current best: 8.638441688058524e-80, Global best: 8.638441688058524e-80, Runtime: 0.01715 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 959, Current best: 8.5169955526175e-80, Global best: 8.5169955526175e-80, Runtime: 0.01618 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 960, Current best: 8.454751448950752e-80, Global best: 8.454751448950752e-80, Runtime: 0.01550 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 961, Current best: 8.387415710313292e-80, Global best: 8.387415710313292e-80, Runtime: 0.01533 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 962, Current best: 8.262358404045746e-80, Global best: 8.262358404045746e-80, Runtime: 0.01541 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 963, Current best: 8.171270618468421e-80, Global best: 8.171270618468421e-80, Runtime: 0.01491 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 964, Current best: 8.113388512026575e-80, Global best: 8.113388512026575e-80, Runtime: 0.01487 seconds
# 2025/05/31 11:28:54 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 965, Current best: 8.030588138376025e-80, Global best: 8.030588138376025e-80, Runtime: 0.01491 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 966, Current best: 7.969474695490477e-80, Global best: 7.969474695490477e-80, Runtime: 0.01487 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 967, Current best: 7.893032630996348e-80, Global best: 7.893032630996348e-80, Runtime: 0.01744 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 968, Current best: 7.830827638484733e-80, Global best: 7.830827638484733e-80, Runtime: 0.02274 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 969, Current best: 7.750279366923536e-80, Global best: 7.750279366923536e-80, Runtime: 0.01622 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 970, Current best: 7.698974582219922e-80, Global best: 7.698974582219922e-80, Runtime: 0.01635 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 971, Current best: 7.660979574650106e-80, Global best: 7.660979574650106e-80, Runtime: 0.02637 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 972, Current best: 7.587519882558222e-80, Global best: 7.587519882558222e-80, Runtime: 0.01571 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 973, Current best: 7.518196445607747e-80, Global best: 7.518196445607747e-80, Runtime: 0.01810 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 974, Current best: 7.460657254376308e-80, Global best: 7.460657254376308e-80, Runtime: 0.01727 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 975, Current best: 7.414705063800958e-80, Global best: 7.414705063800958e-80, Runtime: 0.01657 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 976, Current best: 7.35744228718153e-80, Global best: 7.35744228718153e-80, Runtime: 0.01762 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 977, Current best: 7.305705621564505e-80, Global best: 7.305705621564505e-80, Runtime: 0.01621 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 978, Current best: 7.264318138069985e-80, Global best: 7.264318138069985e-80, Runtime: 0.01845 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 979, Current best: 7.226240486106144e-80, Global best: 7.226240486106144e-80, Runtime: 0.01665 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 980, Current best: 7.18463076115421e-80, Global best: 7.18463076115421e-80, Runtime: 0.01640 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 981, Current best: 7.150354382580474e-80, Global best: 7.150354382580474e-80, Runtime: 0.01564 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 982, Current best: 7.087778346078675e-80, Global best: 7.087778346078675e-80, Runtime: 0.01656 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 983, Current best: 7.065932174650023e-80, Global best: 7.065932174650023e-80, Runtime: 0.01554 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 984, Current best: 7.03485036739132e-80, Global best: 7.03485036739132e-80, Runtime: 0.01599 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 985, Current best: 7.007074373759224e-80, Global best: 7.007074373759224e-80, Runtime: 0.01937 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 986, Current best: 6.970496872369319e-80, Global best: 6.970496872369319e-80, Runtime: 0.02233 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 987, Current best: 6.948945429847098e-80, Global best: 6.948945429847098e-80, Runtime: 0.01633 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 988, Current best: 6.929221822926434e-80, Global best: 6.929221822926434e-80, Runtime: 0.01935 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 989, Current best: 6.905345391304352e-80, Global best: 6.905345391304352e-80, Runtime: 0.01800 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 990, Current best: 6.880275465116086e-80, Global best: 6.880275465116086e-80, Runtime: 0.01819 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 991, Current best: 6.874211540379827e-80, Global best: 6.874211540379827e-80, Runtime: 0.01671 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 992, Current best: 6.857673051232541e-80, Global best: 6.857673051232541e-80, Runtime: 0.01642 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 993, Current best: 6.844784107115544e-80, Global best: 6.844784107115544e-80, Runtime: 0.01647 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 994, Current best: 6.833500283429289e-80, Global best: 6.833500283429289e-80, Runtime: 0.01789 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 995, Current best: 6.82427397788611e-80, Global best: 6.82427397788611e-80, Runtime: 0.01676 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 996, Current best: 6.817133967856305e-80, Global best: 6.817133967856305e-80, Runtime: 0.01754 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 997, Current best: 6.814607460787214e-80, Global best: 6.814607460787214e-80, Runtime: 0.01910 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 998, Current best: 6.809721998423828e-80, Global best: 6.809721998423828e-80, Runtime: 0.01669 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 999, Current best: 6.808699872126948e-80, Global best: 6.808699872126948e-80, Runtime: 0.01611 seconds
# 2025/05/31 11:28:55 PM, INFO, mealpy.swarm_based.GWO.OriginalGWO: >>>Problem: P, Epoch: 1000, Current best: 6.808699872126948e-80, Global best: 6.808699872126948e-80, Runtime: 0.01616 seconds
# Solution: [-4.37671881e-41 -5.06958735e-41 -4.43309035e-41  5.20654847e-41
#  -4.91545644e-41 -4.51668720e-41  4.77423809e-41  4.93216332e-41
#   5.06159788e-41 -4.88116518e-41  4.63810631e-41  4.83756035e-41
#   4.36395603e-41 -4.69264913e-41  4.35354648e-41  4.67328861e-41
#  -3.65246785e-41 -5.35504554e-41 -4.76840052e-41 -4.97336978e-41
#  -4.65047126e-41 -4.31271532e-41 -5.24411888e-41 -4.76555201e-41
#   4.70971112e-41  5.12496077e-41  4.94588921e-41 -4.70240050e-41
#  -5.02893941e-41 -4.59519367e-41], Fitness: Objectives: [6.80869987e-80], Fitness: 6.808699872126948e-80
# Selected feature indices: [3, 6, 7, 8, 10, 11, 12, 14, 15, 24, 25, 26]
# Fitness (1 - F1 score): Objectives: [6.80869987e-80], Fitness: 6.808699872126948e-80
# Estimated F1 score: 6.808699872126948e-80

# %% [markdown]
# ### Discretising to create observation sequences

# %%
from sklearn.cluster import KMeans

features_malware = malware_df.iloc[:,3:-2]


kmeans = KMeans(n_clusters=5)

df_discretized = features_malware.apply(lambda x: kmeans.fit_predict(x.values.reshape(-1, 1)))

malware_df['Observation_Sequence'] = df_discretized.apply(lambda row: ','.join(map(str, row)), axis=1)

malware_df.head()


features_benign = benign_df.iloc[:,3:-2]
features_benign.head()

kmeans_b = KMeans(n_clusters=5)

df_discretized = features_benign.apply(lambda x: kmeans_b.fit_predict(x.values.reshape(-1, 1)))

benign_df['Observation_Sequence'] = df_discretized.apply(lambda row: ','.join(map(str, row)), axis=1)

benign_df.head()

# %% [markdown]
# ### Training seperate markov models
#
# Malware samples markov model

# %%
import numpy as np
from hmmlearn import hmm

# Extract sequences of observations for each sample
sequences_malware = [list(map(int, seq.split(','))) for seq in malware_df['Observation_Sequence']]
lengths = [len(seq) for seq in sequences_malware]

# Train HMM (use GaussianHMM if continuous or MultinomialHMM if discrete)
model_malware = hmm.MultinomialHMM(n_components=3, n_iter=100)  # 3 hidden states
X = np.concatenate(sequences_malware).reshape(-1, 1)

# Train the HMM on the observation sequences
model_malware.fit(X, lengths)

# %% [markdown]
# Benign samples model

# %%
# Extract sequences of observations for each sample
sequences_benign = [list(map(int, seq.split(','))) for seq in benign_df['Observation_Sequence']]
lengths = [len(seq) for seq in sequences_benign]

# Train HMM (use GaussianHMM if continuous or MultinomialHMM if discrete)
model_benign = hmm.MultinomialHMM(n_components=3, n_iter=100)  # 3 hidden states
X = np.concatenate(sequences_benign).reshape(-1, 1)

# Train the HMM on the observation sequences
model_benign.fit(X, lengths)

# %% [markdown]
# Metrics, change model var to display as necessary

# %%
# log_likelihood = model.score(X)
# print(f"Log Likelihood: {log_likelihood}")


# print("Number of hidden states:", model.n_components)


# print("Maximum iterations:", model.n_iter)
# print("Did the model converge?", model.monitor_.converged, "\n\n")

# print("Transition matrix (A):")
# print(model.transmat_)

# print("\n\nEmission probabilities (B):")
# print(model.emissionprob_)


# print("\n\nInitial state probabilities (π):")
# print(model.startprob_)

# %%
# params = model.get_params()
# print("HMM Parameters:")
# print(params)

# %% [markdown]
# Adding the scores to the dataframes

# %%
def add_hmm_scores(df_m, df_b, benign_hmm, malware_hmm):
    # Convert sequences to proper format for HMM
    sequences_m = [list(map(int, seq.split(','))) for seq in df_m['Observation_Sequence']]
    sequences_b = [list(map(int, seq.split(','))) for seq in df_b['Observation_Sequence']]

    # Calculate scores for each sequence
    malware_scores = []
    for seq in sequences_m:
        # Reshape the sequence and compute the score
        score = malware_hmm.score(np.array(seq).reshape(-1, 1))
        malware_scores.append(score)

    benign_scores = []
    for seq in sequences_b:
        # Reshape the sequence and compute the score
        score = benign_hmm.score(np.array(seq).reshape(-1, 1))
        benign_scores.append(score)

    # Add scores as new columns
    df_m['malware_hmm_score'] = malware_scores
    df_b['benign_hmm_score'] = benign_scores

    return df_m, df_b

# Add scores to train and test dataframes
malware_df, benign_df = add_hmm_scores(malware_df, benign_df, model_benign, model_malware)

# %% [markdown]
# Check dataframes

# %%
malware_df.head()

# %% [markdown]
# Reorder columns

# %%
# Swap the last two columns with the two columns before them
cols = malware_df.columns.tolist()
# Swap the last two with the two before them
cols[-4:-2], cols[-2:] = cols[-2:], cols[-4:-2]

# Reorder the DataFrame using the new column order
malware_df = malware_df[cols]

malware_df.head()

# Swap the last two columns with the two columns before them
cols = benign_df.columns.tolist()
# Swap the last two with the two before them
cols[-4:-2], cols[-2:] = cols[-2:], cols[-4:-2]

# Reorder the DataFrame using the new column order
benign_df = benign_df[cols]

malware_df.head()

# %% [markdown]
# Temporal test train splitting

# %%
# Step 3: Concatenate both datasets
combined_df = pd.concat([benign_df, malware_df])

# Step 4: Shuffle the combined data
shuffled_df = shuffle(combined_df, random_state=42)
shuffled_df["Year "].isnull().sum()

# fill nan values
cols = shuffled_df[-2:]
shuffled_df= shuffled_df.fillna(0)


train_df = shuffled_df[shuffled_df['Year ']<2020]
test_df = shuffled_df[shuffled_df['Year ']>=2020]

train_df.tail()

# %% [markdown]
# code that prints number of samples that are past the year 2020, and all that are before

# %%
# Samples with Year > 2020
count_after_2020 = (shuffled_df["Year "] > 2020).sum()
print("Samples after 2020:", count_after_2020)

# Samples with Year <= 2020
count_before_or_in_2020 = (shuffled_df["Year "] <= 2020).sum()
print("Samples in or before 2020:", count_before_or_in_2020)

# %% [markdown]
# Label encode the month column

# %%
train_df_features = train_df.iloc[:, 1:-3]
train_df_labels = train_df.iloc[:,-2]

test_df_features = test_df.iloc[:,1:-3]
test_df_labels = test_df.iloc[:,-2]

train_df_labels.head()

# %%
print(train_df.iloc[:, 1:-5].index.equals(train_df.iloc[:, -2:].index))

# %% [markdown]
# Fixing messed up values in month column

# %%
train_df_features['Month'].unique()

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Define a mapping for misspelled and inconsistent month values
month_corrections = {
    'January': 'January', 'Jan': 'January',
    'February': 'February', 'February ': 'February',
    'March': 'March', 'Marh': 'March', 'March ': 'March',
    'April': 'April',
    'May': 'May', ' May': 'May', 'mAY': 'May',
    'June': 'June', 'June ': 'June',
    'July': 'July', 'July ': 'July',
    'August': 'August', 'August ': 'August',
    'September': 'September', 'September ': 'September', 'September  ': 'September',
    'October': 'October', 'October ': 'October',
    'November': 'November', 'November ': 'November', 'Novembber': 'November', 'november ': 'November',
    'December': 'December', 'December ': 'December', 'Dececmber ': 'December', 'Devember': 'December', 'Dember ': 'December'
}

# Clean the column by stripping extra spaces, converting to title case, and mapping values
train_df_features['Month'] = train_df_features['Month'].str.strip().str.title()  # Remove extra spaces and ensure proper case
train_df_features['Month'] = train_df_features['Month'].map(month_corrections)  # Map corrected values

imputer = SimpleImputer(strategy='most_frequent')

# Fix: Extract the first column (ravel()) from the 2D array returned by fit_transform
train_df_features['Month'] = imputer.fit_transform(train_df_features[['Month']]).ravel()

# Verify unique values after cleaning
print(train_df_features['Month'].unique())
print(train_df_features['Month'].isna().sum())

# Apply same to test features dataset
test_df_features['Month'] = test_df_features['Month'].str.strip().str.title()
test_df_features['Month'] = test_df_features['Month'].map(month_corrections)

# For the test data, we should use transform() instead of fit_transform() to use the same imputer
test_df_features['Month'] = imputer.transform(test_df_features[['Month']]).ravel()

print(test_df_features['Month'].unique())
print(test_df_features['Month'].isna().sum())

# %% [markdown]
# Label encoding the month columns

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# Transform the datasets
train_df_features['Month'] = label_encoder.fit_transform(train_df_features['Month'])
test_df_features['Month'] = label_encoder.fit_transform(test_df_features['Month'])

train_df_features.head()

# %% [markdown]
# Applying standard scaling to the datasets

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()


train_df_features.iloc[:,:-2] = sc.fit_transform(train_df_features.iloc[:,:-2])
test_df_features.iloc[:,:-2] = sc.fit_transform(test_df_features.iloc[:,:-2])

train_df_features = train_df_features.iloc[:,:-2]
test_df_features = test_df_features.iloc[:,:-2]

test_df_features.head()

# %% [markdown]
# Converting the dataframes to pytorch tensors

# %%
# train features and labels
train_features = train_df_features.values
train_labels = train_df_labels.values

# test features and labels
test_features = test_df_features.values
test_labels = test_df_labels.values

# print(train_df_features[].dtypes)
print(train_df_labels.dtypes)


train_features_tensor = torch.tensor(train_features, dtype=torch.float32)
train_labels_tensor = torch.tensor(train_labels, dtype=torch.int)

test_features_tensor = torch.tensor(test_features, dtype=torch.float32)
test_labels_tensor = torch.tensor(test_labels, dtype=torch.int)

train_labels_tensor.shape

# %% [markdown]
# checking data ranges and ensuring no null values in tensors

# %%
print(torch.isnan(test_features_tensor).sum())  # Count NaN values
print(torch.isinf(test_features_tensor).sum())  # Count Inf values
print(test_features_tensor.max(), test_features_tensor.min())  # Check for extreme values

# %%
print(torch.unique(train_labels_tensor))

# %% [markdown]
# Building the autoencoder

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

import time
import psutil
import os
import torch.cuda

# First, check the actual input dimension
actual_input_dim = train_features_tensor.shape[1]  # Should be 57 based on the error
print(f"Actual input dimension: {actual_input_dim}")

# Define the Autoencoder model with correct input dimension
class DeepAutoencoder(nn.Module):
    def __init__(self, input_dim):
        super(DeepAutoencoder, self).__init__()
        
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 50),
            nn.BatchNorm1d(50),
            nn.ReLU(),
            nn.Linear(50, 30),
            nn.BatchNorm1d(30),
            nn.ReLU(),
            nn.Linear(30, 60),
            nn.BatchNorm1d(60),
            nn.ReLU(),
            nn.Linear(60, 12)  # Latent layer
        )
        
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(12, 60),
            nn.BatchNorm1d(60),
            nn.ReLU(),
            nn.Linear(60, 30),
            nn.BatchNorm1d(30),
            nn.ReLU(),
            nn.Linear(30, 50),
            nn.BatchNorm1d(50),
            nn.ReLU(),
            nn.Linear(50, input_dim),
            nn.Sigmoid()  # Output layer with Sigmoid
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Hyperparameters
learning_rate = 0.001
epochs = 30
batch_size = 20

# Instantiate the model with the correct input dimension
model = DeepAutoencoder(actual_input_dim)
criterion = nn.MSELoss()  # Mean Squared Error as loss
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Prepare data
train_loader = DataLoader(TensorDataset(train_features_tensor), batch_size=batch_size, shuffle=True)

# Optional: warm-up or dummy pass (to trigger memory allocation)
with torch.no_grad():
    dummy_input = next(iter(train_loader))[0]
    _ = model(dummy_input)


# Now start timer and memory tracking
process = psutil.Process(os.getpid())
start_time = time.time()
start_memory = process.memory_info().rss / (1024 ** 2)  # MB
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()

epoch_losses = []  # <- Add this before the training loop
total_memory = 0

# Training loop
for epoch in range(epochs):
    running_loss = 0.0
    for batch in train_loader:
        inputs, = batch  # Unpack tuple from DataLoader
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    avg_loss = running_loss / len(train_loader)
    epoch_losses.append(avg_loss)  # <- Store the average loss for this epoch
    print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}")
    current_memory = process.memory_info().rss / (1024 ** 2)
    total_memory += current_memory
    
#  End Timer and memory tracking
end_time = time.time()
total_time = end_time - start_time

print(f"\nTotal training time: {total_time:.2f} seconds")
print(f"CPU memory used: {total_memory:.2f} MB")

# If using GPU
if torch.cuda.is_available():
    gpu_memory = torch.cuda.max_memory_allocated() / (1024 ** 2)
    print(f"Peak GPU memory allocated: {gpu_memory:.2f} MB")

# After training, keep only the encoder for feature extraction
trained_encoder = model.encoder

# %% [markdown]
# Extract latent features from the hidden layer

# %%
import numpy as np

# Extract latent features using the trained encoder
def extract_latent_features(encoder, dataloader):
    encoder.eval()  # Set encoder to evaluation mode
    latent_features = []

    with torch.no_grad():  # Disable gradient calculation
        for batch in dataloader:
            inputs, = batch  
            latent = encoder(inputs)  
            latent_features.append(latent.cpu().numpy())

    return np.concatenate(latent_features, axis=0)

# Create a DataLoader for the train dataset
train_full_loader = DataLoader(TensorDataset(train_features_tensor), batch_size=batch_size, shuffle=False)
# DataLoader for the test dataset
test_full_loader = DataLoader(TensorDataset(test_features_tensor), batch_size=batch_size, shuffle=False) 

# Extract latent features from the encoder
train_latent_features = extract_latent_features(trained_encoder, train_full_loader)
test_latent_features = extract_latent_features(trained_encoder, test_full_loader)
# Now latent_features contains the compressed representations of the data
print("Latent train features shape:", train_latent_features.shape)
print("Latent test features shape:", test_latent_features.shape)

print("latent train labels shape:", train_labels.shape)

# %% [markdown]
# Building the stacked ensemble

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, roc_curve, auc
import numpy as np


# Use latent features and their corresponding labels
X_train_latent = train_latent_features
X_test_latent = test_latent_features
y_train_latent = train_labels
y_test_latent = test_labels

print(y_train_latent.shape)

# Base Classifiers
base_clf1 = SVC(probability=True, random_state=42)  # Support Vector Machine
base_clf2 = LogisticRegression(random_state=42)    # Logistic Regression
base_clf3 = SGDClassifier(loss="log_loss", random_state=42)  # Stochastic Gradient Descent with log loss

# Train the base classifiers on latent features
base_clf1.fit(X_train_latent, y_train_latent)
base_clf2.fit(X_train_latent, y_train_latent)
base_clf3.fit(X_train_latent, y_train_latent)

# Generate predictions (probabilities) for the meta-classifier
train_meta_features = np.column_stack([
    base_clf1.predict_proba(X_train_latent)[:, 1],
    base_clf2.predict_proba(X_train_latent)[:, 1],
    base_clf3.predict_proba(X_train_latent)[:, 1]
])

# Meta-Classifier: CatBoost
meta_clf = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=4, random_state=42, verbose=0)
meta_clf.fit(train_meta_features, y_train_latent)

# Measure full ensemble inference time
start_time = time.time()

# Base classifiers: get test set probabilities (part of inference!)
test_meta_features = np.column_stack([
    base_clf1.predict_proba(X_test_latent)[:, 1],
    base_clf2.predict_proba(X_test_latent)[:, 1],
    base_clf3.predict_proba(X_test_latent)[:, 1]
])

# Meta-classifier makes final prediction
y_pred = meta_clf.predict(test_meta_features)
end_time = time.time()
inference_time = end_time - start_time
# inference_formatted = f"{(inference_time)*1000:.2f}"
inference_formatted = round(inference_time*1000,2)

average_time_per_sample = inference_formatted / len(test_meta_features)
# print(len(test_meta_features))

print(f"Inference time (total): {inference_formatted} Ms")
print(f"Average inference time per sample: {average_time_per_sample:.2f} Ms")



# Predictions and Evaluation
# y_pred = meta_clf.predict(test_meta_features)
print("Classification Report:\n", classification_report(y_test_latent, y_pred))

# %% [markdown]
# Final model evaluation metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

accuracy = accuracy_score(y_test_latent, y_pred)
precision = precision_score(y_test_latent, y_pred)
recall = recall_score(y_test_latent, y_pred)
f1 = f1_score(y_test_latent, y_pred)
roc_auc = roc_auc_score(y_test_latent, meta_clf.predict_proba(test_meta_features)[:, 1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC-AUC: {roc_auc:.4f}")

# %% [markdown]
# ### Comparative Analysis

# %%
from catboost import train
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import FuncFormatter



def show_float(x, pos):
    return f'{x:.2f}'  # Adjust .4f to control decimal places


# Metrics for comparison (sample values, replace with your actual results)
models = ['Autoencoder + Ensemble', 'ResNet + Ensemble']
accuracy = [0.9986, 0.9998]
f1_score = [0.9986, 0.9998]
training_times = [total_time, 127.75]  # seconds (replace with actual training time for ResNet)
inference_times = [inference_time, 555.62]   # seconds

# Set seaborn style
sns.set(style="whitegrid")

# Bar Chart: Accuracy, F1, Training, Inference Time
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
metrics = [accuracy, f1_score, training_times ,inference_times]
titles = ['Accuracy', 'F1 Score', 'Training Time (s)', 'Inference Time (Ms)']
colors = ['skyblue', 'salmon']

for ax, metric, title in zip(axes.flatten(), metrics, titles):
    sns.barplot(x=models, y=metric, palette=colors, ax=ax)
    ax.set_title(title)
    ax.set_ylim(0, max(metric)*1.2)

plt.tight_layout()
plt.show()

# Line Plot: Loss per Epoch (Replace with your actual epoch loss values)
epochs = list(range(1, 31))
loss_autoencoder = epoch_losses
# loss_resnet = [0.48, 0.40, 0.34, 0.29, 0.25, 0.22, 0.20, 0.19, 0.18, 0.17]

plt.figure(figsize=(8, 5))
plt.plot(epochs, loss_autoencoder, label='Autoencoder', marker='o')
# plt.plot(epochs, loss_resnet, label='ResNet', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Loss Convergence per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Plotting ROC curve

# %%
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test_latent, meta_clf.predict_proba(test_meta_features)[:, 1])
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend()
plt.grid()
plt.show()
